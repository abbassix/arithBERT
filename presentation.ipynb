import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot')

# add alpha channel to the color to make it lighter
plt.figure(facecolor='white')

# use more gray ticks for vertical axis
plt.yticks(np.arange(0, 101, 10))

# use more ticks for horizontal axis
plt.xticks(np.arange(0, 11))

# chnage grid color to light gray
plt.grid(color='#e9e9e9')

# use lighter background for the plot
plt.gca().set_facecolor('#f9f9f9')

epochs = np.arange(0, 11)

single_digit_acc = [x[0] for x in single_digit_accuracy]
double_digit_acc = [x[0] for x in double_digit_accuracy]
single_digit_reframed_acc = [x[0] for x in single_digit_reframed_accuracy]
double_digit_reframed_acc = [x[0] for x in double_digit_reframed_accuracy]

plt.plot(epochs, single_digit_reframed_acc, label='Single-digit Reframed', color="blue", alpha=0.5)
plt.plot(epochs, single_digit_acc, label='Single-digit', color="red", alpha=0.5)
plt.plot(epochs, double_digit_reframed_acc, label='Double-digit Reframed', color="lightblue", alpha=0.9)
plt.plot(epochs, double_digit_acc, label='Double-digit', color="lightcoral", alpha=0.7)

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('')  # Impact of Numerical Reframing on Model Accuracy
plt.legend()
plt.show()

# %%
# for `single_digit_accuracy` and `double_digit_accuracy` draw a line plot
# with x-axis as the number of epochs and y-axis as the accuracy.
# accuracy is given as the first element of the tuple in the list.

import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot')

# add alpha channel to the color to make it lighter
plt.figure(facecolor='white')

# use more gray ticks for vertical axis
plt.yticks(np.arange(0, 101, 10))

# use more ticks for horizontal axis
plt.xticks(np.arange(0, 11))

# chnage grid color to light gray
plt.grid(color='#e9e9e9')

# use lighter background for the plot
plt.gca().set_facecolor('#f9f9f9')

epochs = np.arange(0, 11)

single_digit_reframed_acc = [x[0] for x in single_digit_reframed_accuracy]
double_digit_reframed_acc = [x[0] for x in double_digit_reframed_accuracy]
single_digit_reframed_bert_acc = [x[0] for x in single_digit_reframed_bert_accuracy]
double_digit_reframed_bert_acc = [x[0] for x in double_digit_reframed_bert_accuracy]

plt.plot(epochs, single_digit_reframed_acc, label='Single-digit on distilBERTbase', color="blue", alpha=0.5)
plt.plot(epochs, single_digit_reframed_bert_acc, label='Single-digit on BERTbase', color="red", alpha=0.5)
plt.plot(epochs, double_digit_reframed_acc, label='Double-digit on distilBERTbase', color="lightblue", alpha=0.9)
plt.plot(epochs, double_digit_reframed_bert_acc, label='Double-digit on BERTbase', color="lightcoral", alpha=0.7)

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('')  # Performance Comparison: BERTbase vs. distilBERTbase
plt.legend()
plt.show()

# %%
# for `single_digit_accuracy` and `double_digit_accuracy` draw a line plot
# with x-axis as the number of epochs and y-axis as the accuracy.
# accuracy is given as the first element of the tuple in the list.

import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot')

# add alpha channel to the color to make it lighter
plt.figure(facecolor='white')

# use more gray ticks for vertical axis
plt.yticks(np.arange(0, 101, 10))

# use more ticks for horizontal axis
plt.xticks(np.arange(0, 11))

# chnage grid color to light gray
plt.grid(color='#e9e9e9')

# use lighter background for the plot
plt.gca().set_facecolor('#f9f9f9')

epochs = np.arange(0, 11)

single_digit_reframed_acc = [x[0] for x in single_digit_reframed_accuracy]
double_digit_reframed_acc = [x[0] for x in double_digit_reframed_accuracy]
single_digit_reframed_noncustom_acc = [x[0] for x in single_digit_reframed_noncustom_accuracy]
double_digit_reframed_noncustom_acc = [x[0] for x in double_digit_reframed_noncustom_accuracy]

plt.plot(epochs, single_digit_reframed_acc, label='Single-digit with custom masking', color="blue", alpha=0.5)
plt.plot(epochs, single_digit_reframed_noncustom_acc, label='Single-digit with default masking', color="red", alpha=0.5)
plt.plot(epochs, double_digit_reframed_acc, label='Double-digit with custom masking', color="lightblue", alpha=0.9)
plt.plot(epochs, double_digit_reframed_noncustom_acc, label='Double-digit with default masking', color="lightcoral", alpha=0.7)

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('')  # Accuracy Using Custom vs. Default Masking Mechanisms
plt.legend(loc='center right', bbox_to_anchor=(1, 0.4))
plt.show()

# %%
eval_loss= [0.36304834485054016, 0.059116486459970474, 0.00929215643554926, 0.000667352753225714, 0.00039726190152578056, 0.00019176957721356302, 6.339078390737996e-05, 3.6566067137755454e-05, 1.5641242498531938e-05, 4.526551037997706e-06]
train_loss = [1.238090447619953, 0.4594577688031492, 0.205006675382631, 0.06661669553908627, 0.06708939307558853, 0.0034468097496876673, 0.015475226714547756, 0.006495054844206413, 0.0050266036945106705,  0.0010665326783087401]

eval_loss_ref = [0.6609126329421997, 0.05842384323477745, 0.007760278880596161, 0.0026394303422421217, 0.0013213471975177526, 0.000576815742533654, 0.0007748240604996681, 0.00023171340581029654, 8.567969780415297e-05, 6.673810275970027e-05]
train_loss_ref = [1.4591071204801576, 0.42847780210781944, 0.14473650096792035, 0.048408879642992945, 0.027289048760338167, 0.006420599148336765, 0.008389820567274515, 0.004068221138641898, 0.003989936503688846, 0.0022973774281223264]

# %%
# for `eval_loss` and `train_loss` draw a line plot
# with x-axis as the number of epochs and y-axis as the loss.

plt.style.use('ggplot')

# chnage grid color to light gray
plt.grid(color='#e9e9e9')

# use lighter background for the plot
plt.gca().set_facecolor('#f9f9f9')

# use more ticks for horizontal axis
plt.xticks(np.arange(1, 11))

epochs = np.arange(1, 11)

plt.plot(epochs, eval_loss, label='Eval Loss')
plt.plot(epochs, eval_loss_ref, label='Eval Loss Reframed')
plt.plot(epochs, train_loss, label='Train Loss')
plt.plot(epochs, train_loss_ref, label='Train Loss Reframed')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train and Validation Loss of Fine-tuning distilBERTbase')
plt.legend()
plt.show()
